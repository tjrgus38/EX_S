# %% [markdown]
# # EX2. 날씨 좋은 월요일 오후 세 시, 자전거 타는 사람은 몇 명?

# %% [markdown]
# - $ mkdir -p ~/aiffel/bike_regression/data
#
# - $ ln -s ~/data/data/* ~/aiffel/bike_regression/data

# %% [markdown]
# ### 2-4 (3). 손실함수 정의하기

# %% [markdown]
# - 손실함수 : "현재의 모델이 **출력하는 값**과 실제 **정답 간의 차이**"

# %%
import pandas as pd
import numpy as np
# Out:
# 슝=3

# %%
macbook = pd.read_csv('~/aiffel/bike_regression/data/macbook.csv')
print(macbook.shape)
macbook.head()
# Out:
# (80, 2)
#    used_years  price
# 0        2.65    175
# 1        3.80     63
# 2        0.95    273
# 3        4.50    133
# 4        4.45    106

# %%
import matplotlib.pyplot as plt
# 실행한 브라우저에서 바로 그림을 볼 수 있게 해줌
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina' # 더 높은 해상도로 출력한다.
print("슝=3")
# Out:
# 슝=3

# %%
import numpy as np

# np.corrcoef(x, y)를 사용합니다.
np.corrcoef(macbook['used_years'], macbook['price'])
# Out:
# array([[ 1.        , -0.78972238],
#        [-0.78972238,  1.        ]])

# %%
plt.scatter(macbook['used_years'], macbook['price'])
plt.show()

# %% [markdown]
# - 사용 연수를 입력받아서 -> 사용 연수가 입력이 됨.
# - 중고가를 예측  -> 적당한 중고가 예측.

# %%
x = macbook["used_years"].values
y = macbook["price"].values
print("슝=3")
# Out:
# 슝=3

# %%
def model(x, w, b):
    y = w * x + b
    return y
print("슝=3")
# Out:
# 슝=3

# %%
model(x=5, w=2, b=1)
# Out:
# 11

# %%
# x축, y축 그리기
plt.axvline(x=0, c='black')
plt.axhline(y=0, c='black')

# y = wx + b 일차함수 그리기
x = np.linspace(0, 8, 9)
y = model(x, w=-20, b=140) # y = -20x + 140
plt.plot(y)

# 나의 (x, y) 점 찍기
x_data = [2, 5, 6]
y_data = [100, 40, 20]
plt.scatter(x_data, y_data, c='r', s=50)

plt.show()

# %%
plt.scatter(macbook['used_years'], macbook['price'])
plt.show()

# %% [markdown]
# ### 아래와 같은 최적의 직선을 그려보자!!
#
# - 기울기와 y절편을 찾아내는 것. 즉, 방정식을 푼다
#     - 학습한다.

# %% [markdown]
# ![%EC%9D%B4%EC%83%81%EC%A0%81.png](attachment:%EC%9D%B4%EC%83%81%EC%A0%81.png)

# %%
w = 3.1
b = 2.3
print("슝=3")

# %%
x = np.linspace(0, 5, 6)
y = model(x, w, b) # y = 3.1x + 2.3
plt.plot(y, c='r')

plt.scatter(macbook['used_years'], macbook['price'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_37/1135018147.py in <module>
#       1 x = np.linspace(0, 5, 6)
# ----> 2 y = model(x, w, b) # y = 3.1x + 2.3
#       3 plt.plot(y, c='r')
#       4
#       5 plt.scatter(macbook['used_years'], macbook['price'])
#
# NameError: name 'model' is not defined
